# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# Here observed that max happiness rank and 75% of Happiness Rank having large difference also in Standard error column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
 corr = df.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
categorical_col =[]
for i in df.dtypes.index:
    if df.dtypes[i] == "object":
         categorical_col.append(i)
print("categorical column:",categorical_col)

numerical_col =[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("numerical columns:",numerical_col)
# Out:
# categorical column: ['Country', 'Region']
# numerical columns: ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
sns.lmplot(x="Economy (GDP per Capita)",y='Happiness Score',data=df,palette="colorblind")

# %%
sns.lmplot(x="Family",y='Happiness Score',data=df,palette="colorblind")

# %%
sns.lmplot(x="Health (Life Expectancy)",y='Happiness Score',data=df,palette="colorblind")

# %%
sns.lmplot(x="Freedom",y='Happiness Score',data=df,palette="colorblind")

# %%
sns.lmplot(x="Trust (Government Corruption)",y='Happiness Score',data=df,palette="colorblind")

# %%
df1=df[['Economy (GDP per Capita)',"Family",'Health (Life Expectancy)',"Freedom","Trust (Government Corruption)","Generosity","Happiness Score"]]

# %%
df1
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Happiness Score
# ...

# %%
plt.figure(figsize=(20,25))
p=1
for i in df1:
    if p<=7:
        plt.subplot(3,4,p)
        sns.regplot(x="Happiness Score",y=i,data=df1,color='r')
        plt.xlabel("Happiness Score")
        plt.ylabel(i)
        
        p+=1
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df1:
    if p<=7:
        plt.subplot(3,4,p)
        sns.scatterplot(x="Happiness Score",y=i,data=df1,color='r')
        plt.xlabel("Happiness Score")
        plt.ylabel(i)
        
        p+=1
plt.show()

# %%
corr = df1.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,25))
p=1
for i in df1:
    if p<=7:
        plt.subplot(5,4,p)
        sns.boxplot(df1[i], palette="Set2_r")
        plt.xlabel(i)
        
        
    p+=1
    
plt.show()

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
out_features =df1[['Economy (GDP per Capita)',"Family",'Health (Life Expectancy)',"Freedom","Trust (Government Corruption)","Generosity"]]
z =np.abs(zscore(out_features))
z
# Out:
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# 2                    1.192861  1.361054                  0.992229  1.469659
# 3                    1.525130  1.251922                  1.035145  1.605131
# 4                    1.194876  1.221204                  1.118054  1.360416
# ..                        ...       ...                       ...       ...
# 153                  1.552987  0.800520                  0.818610  1.087740
# 154                  1.392303  2.346860                  1.263362  0.372033
# 155                  0.455245  1.901086                  0.372199  1.809238
# 156                  2.067566  2.118467                  1.649648  2.064472
# 157                  1.586334  3.134725                  1.404129  0.426621
#
#      Trust (Government Corruption)  Generosity
# ...

# %%
np.where(z>3)
# Out:
# (array([ 27, 128, 147, 153, 157], dtype=int64),
#  array([4, 5, 1, 4, 1], dtype=int64))

# %%
df1 =df1[(z<3).all(axis=1)]
df1.shape
# Out:
# (153, 7)

# %%
df1
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Happiness Score
# ...

# %%
plt.figure(figsize=(10,6),facecolor="white")
plotnumer =1
for col in df1:
    if plotnumer<=4:
        ax =plt.subplot(2,2,plotnumer)
        sns.distplot(df1[col],color="m")
        plt.xlabel(col,fontsize =12)
        plt.yticks(rotation =0,fontsize =10)
    plotnumer+=1
plt.tight_layout()

# %%
df1.skew()
# Out:
# Economy (GDP per Capita)        -0.392269
# Family                          -0.803145
# Health (Life Expectancy)        -0.741582
# Freedom                         -0.397454
# Trust (Government Corruption)    1.280533
# Generosity                       0.636850
# Happiness Score                  0.133600
# dtype: float64

# %%
df1["Family"] =np.cbrt(df1["Family"])
df1["Health (Life Expectancy)"] =np.cbrt(df1["Health (Life Expectancy)"])
df1["Trust (Government Corruption)"] =np.cbrt(df1["Trust (Government Corruption)"])
df1["Generosity"] =np.cbrt(df1["Generosity"])

# %%
x =df1.drop("Happiness Score",axis =1)
y = df1['Happiness Score']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x =pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.387893  1.176046                  0.947333  1.586655
# 1                    1.145301  1.325484                  0.962082  1.342816
# 2                    1.204951  1.207744                  0.789511  1.479379
# 3                    1.548840  1.122512                  0.815011  1.614219
# 4                    1.207037  1.098293                  0.863703  1.370646
# ..                        ...       ...                       ...       ...
# 148                 -1.544101 -0.476541                 -1.264039 -0.206619
# 149                 -1.385189 -3.384118                 -1.100629 -1.272021
# 150                 -1.470620 -3.007917                 -1.024649  0.386876
# 151                 -0.500792 -2.241378                  0.395736 -1.784215
# 152                 -2.169499 -2.596496                 -1.530161 -2.038257
#
#      Trust (Government Corruption)  Generosity
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu =0
maxRS =0
for i in range(1,200):
    x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.25,random_state=i)
    lr =LinearRegression()
    lr.fit(x_train,y_train)
    pred =lr.predict(x_test)
    acc =r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS =i
print("Maximum r2 score is",maxAccu,"on_Random_state",maxRS)
# Out:
# Maximum r2 score is 0.8702281866562422 on_Random_state 142

# %%
from sklearn.model_selection import cross_val_score

# %%
score =cross_val_score(lr,x,y)
score
# Out:
# array([ -7.63477827,  -3.56826058,  -5.49038611, -13.23911115,
#         -4.76183052])
