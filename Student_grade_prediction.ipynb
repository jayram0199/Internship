# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df =pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv")

# %%
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['MT-331'].mode()
# Out:
# 0    A
# Name: MT-331, dtype: object

# %%
df['MT-331'].fillna("A")
# Out:
# 0       C
# 1      D+
# 2       A
# 3      D+
# 4      C+
#        ..
# 566     A
# 567     A
# 568     A
# 569    C+
# 570     C
# Name: MT-331, Length: 571, dtype: object

# %%
df['EF-303'].mode()
# Out:
# 0    B
# Name: EF-303, dtype: object

# %%
df["EF-303"].fillna("B")
# Out:
# 0      C-
# 1       D
# 2      C+
# 3       D
# 4      C-
#        ..
# 566     B
# 567     A
# 568     B
# 569     D
# 570     D
# Name: EF-303, Length: 571, dtype: object

# %%
df['HS-304'].mode()
# Out:
# 0    A-
# Name: HS-304, dtype: object

# %%
df['HS-304'].fillna("A-")
# Out:
# 0      C+
# 1      C-
# 2       A
# 3      B-
# 4      A-
#        ..
# 566    A-
# 567     A
# 568    B-
# 569     C
# 570     F
# Name: HS-304, Length: 571, dtype: object

# %%
df['CS-301'].mode()
# Out:
# 0    A-
# Name: CS-301, dtype: object

# %%
df['CS-301'].fillna("A-")
# Out:
# 0       B
# 1      A-
# 2      B+
# 3       D
# 4      B-
#        ..
# 566    A-
# 567     A
# 568    B+
# 569     C
# 570     D
# Name: CS-301, Length: 571, dtype: object

# %%
df['CS-302'].mode()
# Out:
# 0    A-
# Name: CS-302, dtype: object

# %%
df['CS-302'].fillna("CS-302")
# Out:
# 0       C
# 1      D+
# 2      A-
# 3      B-
# 4      A-
#        ..
# 566     A
# 567     A
# 568    B+
# 569    C+
# 570     D
# Name: CS-302, Length: 571, dtype: object

# %%
df["TC-383"].mode()
# Out:
# 0    A
# Name: TC-383, dtype: object

# %%
df["TC-383"].fillna("A")
# Out:
# 0      C+
# 1      C-
# 2       B
# 3      D+
# 4      C+
#        ..
# 566    A+
# 567     A
# 568     A
# 569    C-
# 570     C
# Name: TC-383, Length: 571, dtype: object

# %%
df['MT-442'].mode()
# Out:
# 0    A-
# Name: MT-442, dtype: object

# %%
df["MT-442"].fillna("A-")
# Out:
# 0      B+
# 1      C-
# 2       A
# 3      C-
# 4      A-
#        ..
# 566    A+
# 567    A+
# 568    B+
# 569    C-
# 570    A-
# Name: MT-442, Length: 571, dtype: object

# %%
df["EL-332"].mode()
# Out:
# 0    A-
# Name: EL-332, dtype: object

# %%
df["EL-332"].fillna("A-")
# Out:
# 0       C
# 1       C
# 2      B+
# 3      D+
# 4      A-
#        ..
# 566     A
# 567     A
# 568     B
# 569     D
# 570     F
# Name: EL-332, Length: 571, dtype: object

# %%
df['CS-318'].mode()
# Out:
# 0    A-
# Name: CS-318, dtype: object

# %%
df["CS-318"].fillna('A-')
# Out:
# 0      C-
# 1      A-
# 2      A-
# 3      B+
# 4      B-
#        ..
# 566     A
# 567    A+
# 568    C+
# 569    B-
# 570    C-
# Name: CS-318, Length: 571, dtype: object

# %%
df["CS-306"].mode()
# Out:
# 0    A-
# Name: CS-306, dtype: object

# %%
df['CS-306'].fillna('A-')
# Out:
# 0       C
# 1       D
# 2      A-
# 3      C-
# 4      A-
#        ..
# 566    B+
# 567    A-
# 568    B+
# 569    B+
# 570    D+
# Name: CS-306, Length: 571, dtype: object

# %%
df["CS-312"].mode()
# Out:
# 0    A+
# Name: CS-312, dtype: object

# %%
df['CS-312'].fillna('A+')
# Out:
# 0      C-
# 1      D+
# 2       B
# 3      D+
# 4      B-
#        ..
# 566    A-
# 567    B+
# 568    A-
# 569     D
# 570    C+
# Name: CS-312, Length: 571, dtype: object

# %%
df['CS-403'].mode()
# Out:
# 0    A
# Name: CS-403, dtype: object

# %%
df["CS-403"].fillna("A")
# Out:
# 0      C-
# 1       C
# 2       A
# 3      D+
# 4      B+
#        ..
# 566     A
# 567     A
# 568     A
# 569     B
# 570    B-
# Name: CS-403, Length: 571, dtype: object

# %%
df['CS-421'].mode()
# Out:
# 0    B
# Name: CS-421, dtype: object

# %%
df['CS-421'].fillna('B')
# Out:
# 0      C-
# 1       D
# 2       C
# 3      C-
# 4      B-
#        ..
# 566     A
# 567     A
# 568    B+
# 569    C-
# 570     D
# Name: CS-421, Length: 571, dtype: object

# %%
df['CS-406'].mode()
# Out:
# 0    A-
# Name: CS-406, dtype: object

# %%
df["CS-406"].fillna("A-")
# Out:
# 0      A-
# 1      A-
# 2       A
# 3      B-
# 4      A-
#        ..
# 566     A
# 567    A-
# 568     A
# 569     D
# 570     F
# Name: CS-406, Length: 571, dtype: object

# %%
df['CS-414'].mode()
# Out:
# 0    A
# Name: CS-414, dtype: object

# %%
df['CS-414'].fillna("A")
# Out:
# 0       A
# 1      B-
# 2       A
# 3       B
# 4       A
#        ..
# 566    B+
# 567     B
# 568     C
# 569     C
# 570    C-
# Name: CS-414, Length: 571, dtype: object

# %%
df['CS-419'].mode()
# Out:
# 0    A-
# Name: CS-419, dtype: object

# %%
df['CS-419'].fillna("A-")
# Out:
# 0      C-
# 1       C
# 2       A
# 3      C+
# 4      A-
#        ..
# 566    B+
# 567    A-
# 568    B+
# 569     B
# 570    B+
# Name: CS-419, Length: 571, dtype: object

# %%
df['CS-423'].mode()
# Out:
# 0    A-
# Name: CS-423, dtype: object

# %%
df['CS-423'].fillna('A-')
# Out:
# 0       B
# 1       C
# 2      A-
# 3      C+
# 4      A-
#        ..
# 566     B
# 567     C
# 568    A-
# 569    B-
# 570     D
# Name: CS-423, Length: 571, dtype: object

# %%
df['CS-412'].mode()
# Out:
# 0    A-
# Name: CS-412, dtype: object

# %%
df['CS-412'].fillna('A-')
# Out:
# 0      A-
# 1       B
# 2       A
# 3      C+
# 4       A
#        ..
# 566     A
# 567    A-
# 568    A-
# 569     C
# 570    C-
# Name: CS-412, Length: 571, dtype: object

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   417 non-null    object
#  1   PH-121     417 non-null    object
#  2   HS-101     417 non-null    object
#  3   CY-105     417 non-null    object
#  4   HS-105/12  417 non-null    object
#  5   MT-111     417 non-null    object
#  6   CS-105     417 non-null    object
#  7   CS-106     417 non-null    object
#  8   EL-102     417 non-null    object
#  9   EE-119     417 non-null    object
#  10  ME-107     417 non-null    object
#  11  CS-107     417 non-null    object
#  12  HS-205/20  417 non-null    object
#  13  MT-222     417 non-null    object
#  14  EE-222     417 non-null    object
#  15  MT-224     417 non-null    object
#  16  CS-210     417 non-null    object
#  17  CS-211     417 non-null    object
#  18  CS-203     417 non-null    object
# ...

# %% [markdown]
# As per observation there is no use seat number we will drop it.

# %%
df.drop('Seat No.',axis=1
       )
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
df.describe()
# Out:
#              CGPA
# count  417.000000
# mean     2.990386
# std      0.578246
# min      1.708000
# 25%      2.603000
# 50%      3.033000
# 75%      3.452000
# max      3.985000

# %% [markdown]
# In this data set all featuresa having object datatype so we have change it.

# %%
plt.figure(figsize=(20,30),facecolor="white")
p = 1
for i in df:
    if p <= 43:
        plt.subplot(15,3,p)
        sns.countplot(df[i])
    p+=1
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in df.drop(['CGPA'],axis=1):
    df[i]=le.fit_transform(df[i])
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       412       3       0       0          2       1       0       2
# 567       413       1       0       0          0       0       0       0
# 568       414       3       0       2          4       0       0       0
# 569       415       0       4       9          0       9      10       5
# 570       416       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df.dtypes
# Out:
# Seat No.       int32
# PH-121         int32
# HS-101         int32
# CY-105         int32
# HS-105/12      int32
# MT-111         int32
# CS-105         int32
# CS-106         int32
# EL-102         int32
# EE-119         int32
# ME-107         int32
# CS-107         int32
# HS-205/20      int32
# MT-222         int32
# EE-222         int32
# MT-224         int32
# CS-210         int32
# CS-211         int32
# CS-203         int32
# CS-214         int32
# EE-217         int32
# CS-212         int32
# CS-215         int32
# MT-331         int32
# EF-303         int32
# HS-304         int32
# CS-301         int32
# CS-302         int32
# TC-383         int32
# MT-442         int32
# EL-332         int32
# CS-318         int32
# CS-306         int32
# CS-312         int32
# CS-317         int32
# CS-403         int32
# CS-421         int32
# CS-406         int32
# CS-414         int32
# CS-419         int32
# CS-423         int32
# CS-412         int32
# CGPA         float64
# ...

# %%
for col in df.drop(['CGPA'],axis=1):
    plt.figure(figsize=(6,4))
    sns.catplot(x=col,y='CGPA',data=df,kind='bar')
    plt.show()

# %%
df.corr()
# Out:
#            Seat No.    PH-121    HS-101    CY-105  HS-105/12    MT-111  \
# Seat No.   1.000000 -0.042757 -0.110591 -0.416414  -0.395731 -0.183496
# PH-121    -0.042757  1.000000  0.332027  0.550710   0.477579  0.603121
# HS-101    -0.110591  0.332027  1.000000  0.267115   0.424020  0.388243
# CY-105    -0.416414  0.550710  0.267115  1.000000   0.472247  0.590253
# HS-105/12 -0.395731  0.477579  0.424020  0.472247   1.000000  0.473248
# MT-111    -0.183496  0.603121  0.388243  0.590253   0.473248  1.000000
# CS-105    -0.148516  0.525059  0.359590  0.523124   0.511648  0.484123
# CS-106    -0.305920  0.438631  0.334766  0.487614   0.560176  0.518394
# EL-102     0.028673  0.509461  0.265795  0.399489   0.272761  0.474627
# EE-119     0.017302  0.493301  0.185681  0.406801   0.356189  0.417023
# ME-107     0.106513  0.500757  0.242878  0.391850   0.243408  0.492372
# CS-107    -0.185983  0.455828  0.486061  0.345374   0.518757  0.441822
# ...

# %%
plt.figure(figsize=(50,35))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df.drop(['CGPA'],axis=1)
y=df['CGPA']

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.72790218,  0.84242659,  1.82738001, ...,  1.77274648,
#         -0.64402262, -0.4493643 ],
#        [-1.71959495, -1.12449327,  1.46102546, ...,  0.93839515,
#          0.45812826, -0.04811181],
#        [-1.71128773, -1.12449327, -0.73710184, ..., -1.56465886,
#         -1.01140625, -1.25186929],
#        ...,
#        [ 1.71128773,  0.05565864, -1.8361655 , ...,  0.10404381,
#         -1.01140625, -0.4493643 ],
#        [ 1.71959495, -1.12449327, -0.37074729, ..., -0.31313186,
#          0.09074464,  1.15564567],
#        [ 1.72790218,  1.23581056,  1.46102546, ...,  0.10404381,
#          1.56027915,  1.95815065]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu =0
maxRS =0
for i in range(1,200):
    x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.30,random_state=i)
    lr =LinearRegression()
    lr.fit(x_train,y_train)
    pred =lr.predict(x_test)
    acc =r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS =i
print("Maximum r2 score is",maxAccu,"on_Random_state",maxRS)
# Out:
# Maximum r2 score is 0.993302977458973 on_Random_state 106

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR =LR.predict(x_test)
Pred_Train =LR.predict(x_train)
print("R2 Score:",r2_score(y_test,pred_LR))
print("R2 score on traing values:",r2_score(y_train,Pred_Train)*100)
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Mean absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Root Mean Squared error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 Score: 0.993302977458973
# R2 score on traing values: 99.18980051393696
# Mean Squared Error: 0.002341093647989319
# Mean absolute Error: 0.03882282392123259
# Root Mean Squared error: 0.048384849364127604

# %%
lasso= Lasso()
lasso.fit(x_train,y_train)
pred_ls =lasso.predict(x_test)
Pred_Train =lasso.predict(x_train)
print("R2 Score:",r2_score(y_test,pred_LR))
print("R2 score on traing values:",r2_score(y_train,Pred_Train)*100)
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Mean absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Root Mean Squared error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 Score: 0.993302977458973
# R2 score on traing values: 0.0
# Mean Squared Error: 0.002341093647989319
# Mean absolute Error: 0.03882282392123259
# Root Mean Squared error: 0.048384849364127604

# %%
rd= Ridge()
rd.fit(x_train,y_train)
pred_rd =rd.predict(x_test)
Pred_Train =rd.predict(x_train)
print("R2 Score:",r2_score(y_test,pred_LR))
print("R2 score on traing values:",r2_score(y_train,Pred_Train)*100)
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Mean absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Root Mean Squared error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 Score: 0.993302977458973
# R2 score on traing values: 99.18977324496848
# Mean Squared Error: 0.002341093647989319
# Mean absolute Error: 0.03882282392123259
# Root Mean Squared error: 0.048384849364127604

# %%
GR= GradientBoostingRegressor()
GR.fit(x_train,y_train)
pred_GR =GR.predict(x_test)
Pred_Train =GR.predict(x_train)
print("R2 Score:",r2_score(y_test,pred_LR))
print("R2 score on traing values:",r2_score(y_train,Pred_Train)*100)
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Mean absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Root Mean Squared error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 Score: 0.993302977458973
# R2 score on traing values: 99.87211312545448
# Mean Squared Error: 0.002341093647989319
# Mean absolute Error: 0.03882282392123259
# Root Mean Squared error: 0.048384849364127604

# %%
RR= RandomForestRegressor()
RR.fit(x_train,y_train)
pred_RR =RR.predict(x_test)
Pred_Train =RR.predict(x_train)
print("R2 Score:",r2_score(y_test,pred_LR))
print("R2 score on traing values:",r2_score(y_train,Pred_Train)*100)
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Mean absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Root Mean Squared error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 Score: 0.993302977458973
# R2 score on traing values: 99.36786756133431
# Mean Squared Error: 0.002341093647989319
# Mean absolute Error: 0.03882282392123259
# Root Mean Squared error: 0.048384849364127604

# %%
DR= DecisionTreeRegressor()
DR.fit(x_train,y_train)
pred_DR =DR.predict(x_test)
Pred_Train =DR.predict(x_train)
print("R2 Score:",r2_score(y_test,pred_LR))
print("R2 score on traing values:",r2_score(y_train,Pred_Train)*100)
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Mean absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Root Mean Squared error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 Score: 0.993302977458973
# R2 score on traing values: 100.0
# Mean Squared Error: 0.002341093647989319
# Mean absolute Error: 0.03882282392123259
# Root Mean Squared error: 0.048384849364127604

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn =knn.predict(x_test)
Pred_Train =knn.predict(x_train)
print("R2 Score:",r2_score(y_test,pred_LR))
print("R2 score on traing values:",r2_score(y_train,Pred_Train)*100)
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Mean absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Root Mean Squared error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 Score: 0.993302977458973
# R2 score on traing values: 97.47461025724135
# Mean Squared Error: 0.002341093647989319
# Mean absolute Error: 0.03882282392123259
# Root Mean Squared error: 0.048384849364127604

# %%
grid_paramlr={
    
    'fit_intercept':[True,False],
    'copy_X' : [True,False],
    'positive' :[True,False]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gd_lr=GridSearchCV(estimator=lr,n_jobs=-1,
                  param_grid=grid_paramlr,
                  scoring='accuracy',
                  cv=11)

# %%
gd_lr.fit(x,y)
# Out:
# GridSearchCV(cv=11, estimator=LinearRegression(), n_jobs=-1,
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'positive': [True, False]},
#              scoring='accuracy')

# %%
best_parameters=gd_lr.best_params_
print(best_parameters)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'positive': True}

# %%
lrh=LinearRegression(copy_X=True,fit_intercept=True)

# %%
lrh.fit(x_train,y_train)
pred_test_lrh=lrh.predict(x_test)
print("r2_score is = ",r2_score(y_test,pred_test_lrh)*100)
print('mean_absolute_error = ',mean_absolute_error(y_test,pred_test_lrh))
print('mean_squared_error = ',mean_squared_error(y_test,pred_test_lrh))
print('root_mean_squared_error = ',np.sqrt(mean_squared_error(y_test,pred_test_lrh)))
# Out:
# r2_score is =  99.3302977458973
# mean_absolute_error =  0.03882282392123259
# mean_squared_error =  0.002341093647989319
# root_mean_squared_error =  0.048384849364127604

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test_lrh,color='r')
plt.plot(y_test,y_test,color='r')
plt.xlabel('Actual CGPA',fontsize=14)
plt.ylabel('Predicted CGPA',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.savefig('lrh.png')
plt.show()
